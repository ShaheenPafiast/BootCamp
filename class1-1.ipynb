# %% [markdown]
# ## Variable

# %%
## Say 'Hello' to the world in Python
print("hello")
# Out:
# hello
# 3.10.12 (main, Feb  4 2025, 14:57:36) [GCC 11.4.0]
# 10
# helll

# %%
#What version of Python are we using?
# Check the Python Version

import sys
print(sys.version)
# Out:
# '3.10.12 (main, Feb  4 2025, 14:57:36) [GCC 11.4.0]'

# %%
# What is the value of z where z = x + y?
x =y= 4
z =x+y
print(z)
print("BootCamp")
# Out:
# 8
# BootCamp

# %%
# Types of objects in Python

print(type(12))
#Integers can be negative or positive numbers:

print(type(12.2)) #Floats represent real numbers; they are a superset of integer numbers but also include "numbers with decimals".
sys.float_info

type("Welcome to Bootcamp ML to LLM")

#Converting from one object type to a different object type
print(type(str(float(2))))

print(type(True)) #print(type(1))
print(float(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# 1.0

# %%
type(12)
# Out:
# int

# %% [markdown]
# ## Expression

# %%
#Expressions
print(43 + 60 + 16 + 41)
print(50 - 60)
print((30 + 2) * 60)

#print(x = 43 + 60 + 16 + 41)
print(x)
#print(y=x/60)
# Out:
# 160
# -10
# 1920
# 4

# %%
(30 + 2) * 60
# Out:
# 1920

# %%
#Exercise:
print(6/2)
print(6//2)

print(type("hello"== "world"))

# %% [markdown]
# ## Input variables

# %%
#user input
age_int = input("Enter your age: ")
print(f"You are {age_int} years old.")

price_float = float(input("Enter the price: "))
print(f"The price is {price_float}.")
# Out:
# Enter your age:  33
# You are 33 years old.
# Enter the price:  50
# The price is 50.0.

# %%
# command line input
import sys

if len(sys.argv) > 1:
    first_arg = sys.argv[1]
    print(f"The first command-line argument is: {first_arg}")
else:
    print("No command-line arguments provided.")
# Out:
# The first command-line argument is: -f

# %% [markdown]
# ## String interpolation (f-strings)

# %%
name = "John"
age = 30
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is John and I am 30 years old.

# %%
name = "John"
age = 30
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is John and I am 30 years old.

# %%
#str.format()
print("My name is {} and I am {} years old.".format(name, age))
# Out:
# My name is John and I am 30 years old.

# %%
#another usecase
x = 10
y = 20
print(f"The sum of x and y is {x+y}.")
# Out:
# The sum of x and y is 30.

# %%
#String
regular_string = "C:\new_folder\file.txt"
print("Regular String:", regular_string)

#raw string
raw_string = r"C:\new_folder\file.txt"
print("Raw String:", raw_string)
# Out:
# Regular String: C:
# ew_folderile.txt
# Raw String: C:\new_folder\file.txt

# %%
print(" The BodyGuard \\ is the best album" )
# Out:
#  The BodyGuard \ is the best album

# %% [markdown]
# ## String Indexing, Negative Indexing, Slicing, Stride, operations

# %%
name = "The BodyGuard"
name
# Out:
# 'The BodyGuard'

# %%
# print the first element
print(name[5])
# Out:
# o

# %%
print(name[-1])
# Out:
# d

# %%
len("The BodyGuard")
# Out:
# 13

# %%
# Take the slice on variable name with only index 0 to index 3

name[0:4]
# Out:
# 'The '

# %%
# Take the slice on variable name with only index 8 to index 11

name[4:7]
# Out:
# 'Bod'

# %%
# Get every second element, starting with the index 0. The elments on index 0, 2, 4 ...

name[4::5]
# Out:
# 'Bu'

# %%
# Get every second element in the range from index 0 to index 4

name[0:5:2]  # 3
# Out:
# 'TeB'

# %%
# Concatenate two strings

statement = name + " is the best album"
statement
# Out:
# 'The BodyGuard is the best album'

# %%
3 * "The BodyGuard"
# Out:
# 'The BodyGuardThe BodyGuardThe BodyGuard'

# %%
# Convert all the characters in string to upper case

a = "Thriller is the sixth studio album"
print("before upper:", a)
b = a.upper()
print("After upper:", b)
b = b.lower()
print("After upper:", b)
# Out:
# before upper: Thriller is the sixth studio album
# After upper: THRILLER IS THE SIXTH STUDIO ALBUM
# After upper: thriller is the sixth studio album

# %%
# Replace the old substring with the new target substring is the segment has been found in the string

a = "The BodyGuard is the best album"
b = a.replace('BodyGuard', 'Janet')
b
# Out:
# 'The Janet is the best album'

# %%
# Find the substring in the string.

name.find('Guard') #g
# Out:
# 8

# %%
#string.split(separator, maxsplit)
split_string = (name.split())
split_string
# Out:
# ['The', 'BodyGuard']

# %% [markdown]
# ## RegEx

# %%
pattern = r"\W"  # Matches any non-word character
text = "Hello, world!"
matches = re.findall(pattern, a)

print("Matches:", matches)
# Out:
# Matches: [' ', ' ', ' ', ' ', ' ']

# %%
s2 = "The BodyGuard is the best album of 'Whitney Houston'."


# Use the findall() function to find all occurrences of the "st" in the string
result = re.findall("st", s2)

# Print out the list of matched words
print(result)
# Out:
# ['st', 'st']

# %%
# Use the split function to split the string by the "\s"
split_array = re.split(r"\s", s2)

# The split_array contains all the substrings, split by whitespace characters
print(split_array)
# Out:
# ['The', 'BodyGuard', 'is', 'the', 'best', 'album', 'of', "'Whitney", "Houston'."]

# %%
# Define the regular expression pattern to search for
pattern = r"Whitney Houston"

# Define the replacement string
replacement = "legend"

# Use the sub function to replace the pattern with the replacement string
new_string = re.sub(pattern, replacement, s2, flags=re.IGNORECASE)

# The new_string contains the original string with the pattern replaced by the replacement string
print(new_string)
# Out:
# The BodyGuard is the best album of 'legend'.

# %% [markdown]
# ## Lists

# %%
L=["Michael Jackson",10.1, 1980]
L
# Out:
# ['Michael Jackson', 10.1, 1980]

# %%
print('the same element:\n Postive Index:',L[0],
'\n Negative Negative:' , L[-3]  )

print('the same element:\n Postive Index:',L[1],
'\n Negative Index:' , L[-2]  )

print('the same element:\n Postive Index:',L[2],
'\n Negative Index:' , L[-1]  )
# Out:
# the same element:
#  Postive Index: Michael Jackson
#  Negative Negative: Michael Jackson
# the same element:
#  Postive Index: 10.1
#  Negative Index: 10.1
# the same element:
#  Postive Index: 1982
#  Negative Index: 1982

# %%
# Use extend to add elements to list

L = [ "Michael Jackson", 10.2]
L.extend(['pop', 10])
len(L)
# Out:
# 4

# %%
# Use append to add elements to list

L = [ "Michael Jackson", 10.2]
L.append(['pop', 10])
len(L)
# Out:
# 3

# %%
# Change the element based on the index
A = ["hard rock", 10, 1.2]
B = A
print('A:', A)
print('B:', B)
# Out:
# A: ['hard rock', 10, 1.2]
# B: ['hard rock', 10, 1.2]

# %%
B[0] = "ban"
print('A[0]:', A[0])
# Out:
# A[0]: ban

# %%
B=["hard rock", 10, 1.2]
print('A[0]:', A[0])
# Out:
# A[0]: ban

# %% [markdown]
# ## Tuples

# %%
# Create your first tuple

tuple1 = ("disco",10,1.2 )
tuple1
# Out:
# ('disco', 10, 1.2)

# %%
type(tuple1)
# Out:
# tuple

# %%
# Print the variable on each index

print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
# Out:
# disco
# 10
# 1.2

# %%
# Concatenate two tuples

tuple2 = tuple1 + ("hard rock", 10)
tuple2
# Out:
# ('disco', 10, 1.2, 'hard rock', 10)

# %%
tuple1[-1]
# Out:
# 1.2

# %%
# Slice from index 0 to index 2

print(tuple2[0:3])

len(tuple2)
# Out:
# ('disco', 10, 1.2)
# 5

# %%
# Create a nest tuple

NestedT =(1, 2, ("pop", "rock") ,(3,4),("disco",(1,2)))

# %%
# Print element on each index

print("Element 0 of Tuple: ", NestedT[0])
print("Element 1 of Tuple: ", NestedT[1])
print("Element 2 of Tuple: ", NestedT[2])
print("Element 3 of Tuple: ", NestedT[3])
print("Element 4 of Tuple: ", NestedT[4])
# Out:
# Element 0 of Tuple:  1
# Element 1 of Tuple:  2
# Element 2 of Tuple:  ('pop', 'rock')
# Element 3 of Tuple:  (3, 4)
# Element 4 of Tuple:  ('disco', (1, 2))

# %% [markdown]
# ## Dictionaries

# %%
# Create the dictionary

Dict = {"key1": 1, "key2": "2", "key3": [3, 3, 3], "key4": (4, 4, 4), ('key5'): 5, (0, 1): 6}
Dict
# Out:
# {'key1': 1,
#  'key2': '2',
#  'key3': [3, 3, 3],
#  'key4': (4, 4, 4),
#  'key5': 5,
#  (0, 1): 6}

# %%
Dict[(0, 1)]
# Out:
# 6

# %%
# Create a sample dictionary

release_year_dict = {"Thriller": "1982", "Back in Black": "1980", \
                    "The Dark Side of the Moon": "1973", "The Bodyguard": "1992", \
                    "Bat Out of Hell": "1977", "Their Greatest Hits (1971-1975)": "1976", \
                    "Saturday Night Fever": "1977", "Rumours": "1977"}
release_year_dict
# Out:
# {'Thriller': '1982',
#  'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977'}

# %%
# Get value by key

release_year_dict['The Bodyguard']
# Out:
# '1992'

# %%
release_year_dict.keys()
release_year_dict.values()
# Out:
# dict_values(['1982', '1980', '1973', '1992', '1977', '1976', '1977', '1977'])

# %%
# Append value with key into dictionary

release_year_dict['Graduation'] = '2007'
release_year_dict
# Out:
# {'Thriller': '1982',
#  'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977',
#  'Graduation': '2007'}

# %%
# Delete entries by key

del(release_year_dict['Thriller'])
del(release_year_dict['Graduation'])
release_year_dict
# Out:
# {'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977'}

# %% [markdown]
# ## Set

# %%
# Create a set

set1 = {"pop", "rock", "soul", "hard rock", "rock", "R&B", "rock", "disco"}
set1
# Out:
# {'R&B', 'disco', 'hard rock', 'pop', 'rock', 'soul'}

# %%
# Convert list to set

album_list = [ "Michael Jackson", "Thriller", 1982, "00:42:19",
               "Pop, Rock, R&B", 46.0, 65, "30-Nov-82", None, 10.0]
album_set = set(album_list)
album_set
# Out:
# {'00:42:19',
#  10.0,
#  1982,
#  '30-Nov-82',
#  46.0,
#  65,
#  'Michael Jackson',
#  None,
#  'Pop, Rock, R&B',
#  'Thriller'}

# %%
album_set.add("NSYNC")

# %%
album_set
# Out:
# {'00:42:19',
#  10.0,
#  1982,
#  '30-Nov-82',
#  46.0,
#  65,
#  'Michael Jackson',
#  'NSYNC',
#  None,
#  'Pop, Rock, R&B',
#  'Thriller'}

# %%
# Sample Sets

album_set1 = set(["Thriller", 'AC/DC', 'Back in Black'])
album_set2 = set([ "AC/DC", "Back in Black", "The Dark Side of the Moon"])

# %%
# Find the intersections

intersection = album_set1 & album_set2
intersection
# Out:
# {'AC/DC', 'Back in Black'}

# %%
# Find the difference in set1 but not set2

album_set1.difference(album_set2)
album_set2.difference(album_set1)
# Out:
# {'The Dark Side of the Moon'}

# %%
album_set1.union(album_set2)
# Out:
# {'AC/DC', 'Back in Black', 'The Dark Side of the Moon', 'Thriller'}

# %%
# Check if superset

set(album_set1).issuperset(album_set2)
# Out:
# False

# %%
# Check if subset

set({'Back in Black'}).issubset(album_set1)
# Out:
# True

# %% [markdown]
# # Exercises:

# %% [markdown]
# ## Task 1

# %% [raw]
# Write a Python program that:
# i. Reads a sentence from standard input
# ii. Writes this sentence on standard output all in lower case
# iii. Writes this sentence on standard output with all vowels in upper case and
# all consonants in lower case
# iv. Writes the sentence in reverse order

# %%
#Write your code here

# %% [markdown]
# ## Task 2

# %% [raw]
# Write a Python program that:
# i. Reads a sentence from standard input
# ii. Counts the number of words and the number of characters, not included
# space
# iii. Counts the number of vowels.

# %%
#Write your code here

# %% [markdown]
# ## Task 3

# %% [raw]
# Write a Python program that reads from standard input the amount of a restaurant
# bill and outputs two options for tipping, one based on 15% of the bill, the other
# based on 20% of the bill.

# %%
# Write your code here

# %% [markdown]
# ## Task 4

# %% [raw]
# Write a Python program that:
# i. Reads a sentence
# ii. Remove all vowels
# iii. Replaces all v and b in the original sentence with b and v, respectively (i.e.
# for example string ‘cvvbt’ becomes ‘cbbvt’
# iv. Count number of letters in the modified sentence
# v. Writes the resulting sentence and number of letters on standard output

# %%
# Write your code here
